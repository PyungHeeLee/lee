# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['font.size'] = 15
matplotlib.rcParams['axes.unicode_minus'] = False # 마이너스 글자가 깨지는 현상을 해결

# %%
name=['1번','2번','기타']
value=[47.8,48.6,100-48.6-47.8]
explode=[0.01, 0.01, 0.05]
wedgeprops={'width':0.9, 'edgecolor':'r', 'linewidth':3}

plt.pie(value,labels=name,colors=['b','r','y'], autopct='%.1f%%',startangle=90,counterclock=False,explode=explode,wedgeprops=wedgeprops)
#        값      라벨          색깔                     값 표시     90도에서 시작       시계방향     중심에서 떨어지는 정도
# autopct: %.1f%% %.2f
plt.title('후보별 득표율')
plt.legend(loc=[1.2,0.6], title='후보')
plt.show()

# %%
def auto(pct):
    return '{:.2f}'.format(pct) if pct >= 10 else '' # 10 이상만 값 표시

plt.pie(value, labels=name, autopct=auto)
plt.show()

# %%
df = pd.read_excel('../pandas/suneung.xlsx', index_col='번호')
df
# Out:
#        이름   국어  수학  탐구  출생연도  응시연도  수학가나형통합여부
# 번호
# 0     이평희   86  84  93  1998  2017      False
# 1      친구   92  98  95  1999  2022       True
# 2       형   96  97  92  1994  2012      False
# 3      누나   96  86  94  1996  2013      False
# 4   친구여동생  100  99  97  2000  2021       True
# 5   사촌동생1   89  82  96  1999  2017      False
# 6   사촌동생2   76  65  68  2001  2018      False

# %%
grp = df.groupby('수학가나형통합여부')
grp.size()[True]
# Out:
# 2

# %%
value = [grp.size()[True], grp.size()[False]]
label = ['통합', '미통합']
plt.pie(value, labels=label)
# Out:
# ([<matplotlib.patches.Wedge at 0x24e37626d30>,
# ...
#  [Text(0.6858387475358717, 0.8600146582346299, '통합'),
#   Text(-0.6858386670154851, -0.8600147224474839, '미통합')])
